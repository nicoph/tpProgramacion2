# %% [markdown]
# ### Repaso de clase anterior
# En la clase anterior vimos un nuevo paquete llamado pandas 🐼 que nos permitió leer archivos csv de una forma un poco mas amigable que el paquete `csv`

# %%
import pandas as pd #casi todo el mundo importa pandas así

# %%
data = pd.read_csv('listings.csv.gz')

# %%
data.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  23726706  https://www.airbnb.com/rooms/23726706  20220605131734
# 1  35815036  https://www.airbnb.com/rooms/35815036  20220605131734
# 2  31553121  https://www.airbnb.com/rooms/31553121  20220605131734
# 3  34745823  https://www.airbnb.com/rooms/34745823  20220605131734
# 4  44586947  https://www.airbnb.com/rooms/44586947  20220605131734
#
#   last_scraped                                               name  \
# 0   2022-06-05  Private room 20 minutes from Amsterdam + Break...
# 1   2022-06-05  Vrijstaand vakantiehuis, privé tuin aan het water
# 2   2022-06-05                    Quiet Guesthouse near Amsterdam
# 3   2022-06-05           Apartment ' Landzicht', nearby Amsterdam
# 4   2022-06-05                  Weesp, 2 kamers vlakbij Amsterdam
#
#                                          description  \
# 0  Cousy  private room 20 min. from Amsterdam. Sh...
# 1  Bij het pittoreske dorpje Watergang ligt ons p...
# ...

# %% [markdown]
# Vamos a ver cómo calculamos el precio promedio de los listings? y por barrio?

# %%
data_2 = pd.read_csv('listings.csv')
data_2['price'].mean()
#con el listing completo no anda, con el listing corto si.
# Out:
# 198.01960149036125

# %%
data_2[data_2['neighbourhood']=='Bijlmer-Centrum']['price'].mean()
# Out:
# 142.5731707317073

# %% [markdown]
# ## Manipulación de DFs y Series

# %% [markdown]
# ### Operadores
# Veamos que operaciones podemos aplicarle a una Serie de pandas

# %%
import numpy as np

# %%
df = pd.DataFrame(index = list(range(10)), columns = ['a', 'b', 'c'])
df['a'] = np.random.rand(10,1)
df['b'] = 1
df['c'] = np.random.rand(10,1)
df
# Out:
#           a  b         c
# 0  0.158055  1  0.109705
# 1  0.709789  1  0.194343
# 2  0.572891  1  0.733701
# 3  0.054267  1  0.747775
# 4  0.727996  1  0.235818
# 5  0.145281  1  0.480853
# 6  0.972191  1  0.140046
# 7  0.784969  1  0.910078
# 8  0.309619  1  0.638145
# 9  0.615481  1  0.426317

# %%
# np.random.rand?
#explorar la ayuda

# %%
# suma
df['a'] + df['b']
# Out:
# 0    1.158055
# 1    1.709789
# 2    1.572891
# 3    1.054267
# 4    1.727996
# 5    1.145281
# 6    1.972191
# 7    1.784969
# 8    1.309619
# 9    1.615481
# dtype: float64

# %%
df['d'] = df['a'] + df['b']
df
# Out:
#           a  b         c         d
# 0  0.158055  1  0.109705  1.158055
# 1  0.709789  1  0.194343  1.709789
# 2  0.572891  1  0.733701  1.572891
# 3  0.054267  1  0.747775  1.054267
# 4  0.727996  1  0.235818  1.727996
# 5  0.145281  1  0.480853  1.145281
# 6  0.972191  1  0.140046  1.972191
# 7  0.784969  1  0.910078  1.784969
# 8  0.309619  1  0.638145  1.309619
# 9  0.615481  1  0.426317  1.615481

# %%
# resta
df['a'] - df['b']
# Out:
# 0   -0.841945
# 1   -0.290211
# 2   -0.427109
# 3   -0.945733
# 4   -0.272004
# 5   -0.854719
# 6   -0.027809
# 7   -0.215031
# 8   -0.690381
# 9   -0.384519
# dtype: float64

# %%
# multiplicación
df['a'] * df['b']
# Out:
# 0    0.158055
# 1    0.709789
# 2    0.572891
# 3    0.054267
# 4    0.727996
# 5    0.145281
# 6    0.972191
# 7    0.784969
# 8    0.309619
# 9    0.615481
# dtype: float64

# %% [markdown]
# ### Valor nulo
# Muchas veces, los datos que tenemos presentan valores nulos, NaNs.

# %%
df.loc[10, 'a'] = 2
df
# Out:
#            a    b         c         d
# 0   0.158055  1.0  0.109705  1.158055
# 1   0.709789  1.0  0.194343  1.709789
# 2   0.572891  1.0  0.733701  1.572891
# 3   0.054267  1.0  0.747775  1.054267
# 4   0.727996  1.0  0.235818  1.727996
# 5   0.145281  1.0  0.480853  1.145281
# 6   0.972191  1.0  0.140046  1.972191
# 7   0.784969  1.0  0.910078  1.784969
# 8   0.309619  1.0  0.638145  1.309619
# 9   0.615481  1.0  0.426317  1.615481
# 10  2.000000  NaN       NaN       NaN

# %%
# veamos que pasa cuando recalculamos la columna d
df['d'] = df['a'] + df['b']
df
# Out:
#            a    b         c         d
# 0   0.158055  1.0  0.109705  1.158055
# 1   0.709789  1.0  0.194343  1.709789
# 2   0.572891  1.0  0.733701  1.572891
# 3   0.054267  1.0  0.747775  1.054267
# 4   0.727996  1.0  0.235818  1.727996
# 5   0.145281  1.0  0.480853  1.145281
# 6   0.972191  1.0  0.140046  1.972191
# 7   0.784969  1.0  0.910078  1.784969
# 8   0.309619  1.0  0.638145  1.309619
# 9   0.615481  1.0  0.426317  1.615481
# 10  2.000000  NaN       NaN       NaN

# %% [markdown]
# Cuando queremos sumar dos celdas en la que una hay un valor nulo el resultado es otro valor nulo. Esto tiene sentido ya que pandas no sabe como sumar un valor nulo con un valor no nulo.
#
# Todos estamos tentados de reemplazar ese valor nulo por un cero, no? Pero cómo sabemos si está bien reemplazarlo por un cero o por un -1 o por un 10? La respuesta es que depende del contexto del trabajo que estemos haciendo.
#
# Supongamos que en este trabajo tiene sentido reemplazar el valor nulo por un 0. Tenemos varias formas de hacer eso:
# - reemplazar el NaN por un zero inplace
# - reemplazar el NaN por un zero solo para la operación en cuestión

# %%
df['a'] + df['b'].fillna(0)
# Out:
# 0     1.158055
# 1     1.709789
# 2     1.572891
# 3     1.054267
# 4     1.727996
# 5     1.145281
# 6     1.972191
# 7     1.784969
# 8     1.309619
# 9     1.615481
# 10    2.000000
# dtype: float64

# %%
df['a'].add(df['b'], fill_value = 0)
# Out:
# 0     1.158055
# 1     1.709789
# 2     1.572891
# 3     1.054267
# 4     1.727996
# 5     1.145281
# 6     1.972191
# 7     1.784969
# 8     1.309619
# 9     1.615481
# 10    2.000000
# dtype: float64

# %%
df['b'].fillna(0, inplace = True)
df['b']
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    0.0
# Name: b, dtype: float64

# %% [markdown]
# ### Alineación de índices
# Cuando operamos con dos series, pandas alinea los indices antes de realizar la operación.
# Antes de realizar la operación tenemos que tener en cuenta que:
# - los índices sean únicos
# - los índices sean comunes a las dos series
#
# Sino, van a obtener valores nulos o un resultado erroneo
# ![image.png](data:image/png;base64,...)
#
#
# (Harrison, 2021)

# %% [markdown]
# ### Filtrar Series y Dataframes
# Muchas veces no queremos ver/usar todos los datos dentro del DF/Series y preferimos filtrarlos.
# Para eso generamos una Serie de booleanos que nos van a indicar si el índice en cuestión debe mostrarse o no.
#
# Veamos un ejemplo donde solo queremos ver aquellos registros donde el `review_scores_value` es mayor a 3

# %%
filtro = data['review_scores_value']>3
filtro
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6168     True
# 6169     True
# 6170    False
# 6171     True
# 6172     True
# Name: review_scores_value, Length: 6173, dtype: bool

# %%
data
# Out:
#             id                            listing_url       scrape_id  \
# 0     23726706  https://www.airbnb.com/rooms/23726706  20220605131734
# 1     35815036  https://www.airbnb.com/rooms/35815036  20220605131734
# 2     31553121  https://www.airbnb.com/rooms/31553121  20220605131734
# 3     34745823  https://www.airbnb.com/rooms/34745823  20220605131734
# 4     44586947  https://www.airbnb.com/rooms/44586947  20220605131734
# ...        ...                                    ...             ...
# 6168  48005583  https://www.airbnb.com/rooms/48005583  20220605131734
# 6169  29532926  https://www.airbnb.com/rooms/29532926  20220605131734
# 6170  35760705  https://www.airbnb.com/rooms/35760705  20220605131734
# 6171  36900951  https://www.airbnb.com/rooms/36900951  20220605131734
# 6172  40575103  https://www.airbnb.com/rooms/40575103  20220605131734
#
#      last_scraped                                               name  \
# ...

# %%
len(data), len(data[filtro])
# Out:
# (6173, 5550)

# %%
data[filtro].head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  23726706  https://www.airbnb.com/rooms/23726706  20220605131734
# 1  35815036  https://www.airbnb.com/rooms/35815036  20220605131734
# 2  31553121  https://www.airbnb.com/rooms/31553121  20220605131734
# 3  34745823  https://www.airbnb.com/rooms/34745823  20220605131734
# 4  44586947  https://www.airbnb.com/rooms/44586947  20220605131734
#
#   last_scraped                                               name  \
# 0   2022-06-05  Private room 20 minutes from Amsterdam + Break...
# 1   2022-06-05  Vrijstaand vakantiehuis, privé tuin aan het water
# 2   2022-06-05                    Quiet Guesthouse near Amsterdam
# 3   2022-06-05           Apartment ' Landzicht', nearby Amsterdam
# 4   2022-06-05                  Weesp, 2 kamers vlakbij Amsterdam
#
#                                          description  \
# 0  Cousy  private room 20 min. from Amsterdam. Sh...
# 1  Bij het pittoreske dorpje Watergang ligt ons p...
# ...

# %% [markdown]
# #### Filtro usando cadenas
# Supongamos que queremos filtrar todos los listings que tienen la palabra gato/cat en su descripción porque alguien del grupo de turistas es alergico/a a los 🐱🐱🐱🐱🐱
#
#
# La columna `description` tiene algunos elementos con valores nulos y no nos permite usar filtros. Por lo tanto, vamos a rellenar esos NaNs con algún valor que creamos acorde. Cuando trabajamos con cadenas, es común rellenar los NaNs con un espacio

# %%
data[data['description'].str.contains(' cat ')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-097fb10a41ee> in <module>
# ----> 1 data[data['description'].str.contains(' cat ')]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
data['description'].fillna(' ', inplace = True)

# %%
data[data['description'].str.contains(' cat ')].head(2)
# Out:
#           id                            listing_url       scrape_id  \
# 17  50472290  https://www.airbnb.com/rooms/50472290  20220605131734
# 34     62015     https://www.airbnb.com/rooms/62015  20220605131734
#
#    last_scraped                                               name  \
# 17   2022-06-05     2 bedroom rental unit in Amsterdam with garden
# 34   2022-06-05  Charming, beautifully & sunny place with cat Luna
#
#                                           description  \
# 17  Nice 2 bedrome flat on the ground floor in pea...
# 34  This beautiful apartment in one of the most li...
#
#                                 neighborhood_overview  \
# 17                                                NaN
# 34  In this neighborhood is a lot to do: lots of c...
#
#                                           picture_url   host_id  \
# 17  https://a0.muscache.com/pictures/miso/Hosting-...  53274216
# 34  https://a0.muscache.com/pictures/e6cb417b-6d76...    301340
#
# ...

# %%
data[data['description'].str.contains(' cat ')].loc[17]['description']
# Out:
# 'Nice 2 bedrome flat on the ground floor in peaceful neghbourhoos. Garden with trampoline and garden couch. Close to public transport, canal for swimming, basketball and football field, playgrounds and skateboard park. Perfect for families. 2 skateboards and protection available for your use for children. We prefer longtime renters, that will care for our cat as well, therefore reduced price.'

# %% [markdown]
# #### Filtrar usando más de una condición
# Supongamos que ahora queremos ver los listings con buenas puntuaciones pero ademas que tengan más de 2 habitaciones

# %%
data[(data['review_scores_rating']>4)&(data['bedrooms']>4)].head()
# Out:
#          id                          listing_url       scrape_id last_scraped  \
# 59   283170  https://www.airbnb.com/rooms/283170  20220605131734   2022-06-05
# 67   307497  https://www.airbnb.com/rooms/307497  20220605131734   2022-06-05
# 160  742160  https://www.airbnb.com/rooms/742160  20220605131734   2022-06-05
# 202  874688  https://www.airbnb.com/rooms/874688  20220605131734   2022-06-05
# 220  934060  https://www.airbnb.com/rooms/934060  20220605131734   2022-06-05
#
#                                       name  \
# 59      5-bedrooms house; central location
# 67   Sailing ship group stays in Amsterdam
# 160  Sailing ship group stays in Amsterdam
# 202        5 BR apartment / Quiet / Garden
# 220      LOTUS, Classic Dutch Saling Barge
#
#                                            description  \
# 59   The apartment is a modern five bedroom apartme...
# 67   Welcome on board of our historical sailing shi...
# 160  Welcome on board of our historical sailing shi...
# ...

# %% [markdown]
# ### Filtrar usando una isnull(), notnull()
# Muchas veces queremos saber si alguna variable tiene datos nulos.

# %%
data[data['host_neighbourhood'].isnull()][['host_neighbourhood']].head()
# Out:
#   host_neighbourhood
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
data[data['host_neighbourhood'].notnull()][['host_neighbourhood']].head()
# Out:
#      host_neighbourhood
# 24       Indische Buurt
# 25       Grachtengordel
# 26  Westelijke Eilanden
# 27    Amsterdam Centrum
# 28    Amsterdam Centrum

# %% [markdown]
# ### Duplicated, Sort, Unique
# Supongamos que no queremos tener valores rerpetidos de listings.
# 1. Vamos a fijarnos si tenemos valores repetidos. Eso lo podemos hacer con el método `.duplicated`

# %%
data[data['listing_url'].duplicated(keep = 'first')]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# Por lo que vemos arriba, en este dataset no hay listings repetidos.
#
# Se ve que lo limpiaron bien 🧹🧹🧹🧹🧹🧹
#
# Supongamos solo queremos tener un listing por `host_id` para poder calcular `host_total_listings_count` medio de esta ciudad

# %%
data[~(data['host_id'].duplicated(keep = 'last'))]['host_total_listings_count'].mean()
# Out:
# 1.984950495049505

# %%
# Chequeamos que la longitud del dataframe resultante sea la misma que la cantidad de host_ids unicos
len(data[~(data['host_id'].duplicated(keep = 'last'))]), len(data['host_id'].unique())
# Out:
# (5050, 5050)

# %%
data[~(data['host_id'].duplicated(keep = 'last'))]['host_total_listings_count'].median()
# Out:
# 1.0

# %% [markdown]
# Ahora supongamos que queremos quedarnos con un único registro por host pero quedarnos solo con aquel registro que tiene la mayor cantidad de `bedrooms`. Entonces, primero, ordenamos los datos y luego los filtramos con `duplicated`

# %%
data.sort_values(by = 'bedrooms', inplace = True, ascending = False)

# %%
# luego, miremos cuales son os host_ids que estan duplicados para tener una idea
data[data['host_id'].duplicated(keep = False)]['host_id']
# Out:
# 1277     18081564
# 67        1582128
# 2371     22879651
# 3149      5037506
# 160       1582128
#           ...
# 6140    214764531
# 6143    214764531
# 6161    384216171
# 6166    384216171
# 6168    384216171
# Name: host_id, Length: 1667, dtype: int64

# %%
# miramos un ejemplo en particular
data[data['host_id'] == 4271294][['bedrooms']]
# Out:
#       bedrooms
# 3531       2.0
# 4050       1.0
# 3689       1.0

# %%
data[(~(data['host_id'].duplicated(keep = 'first')))&(data['host_id']==4271294)][['bedrooms']]
# Out:
#       bedrooms
# 3531       2.0

# %% [markdown]
# ## Tipos de datos
# Como ya se habrán dado cuenta, los datos dentro de las Series y los DFs tiene un tipo de dato 🤷
# Los datos puede ser de cualquier tipo y los podemos pasar de un tipo de dato a otro.
#
# Abajo vemos que el id es un número.  Muchas veces, resulta útil guardar los ids como strings. Esto lo podemos hacer con el método `astype`

# %%
data['id'].head(5).tolist()
# Out:
# [9990099, 307497, 20840176, 29874862, 742160]

# %%
data['id'] = data['id'].astype('str')

# %%
data['id'].head(5).tolist()
# Out:
# ['9990099', '307497', '20840176', '29874862', '742160']

# %% [markdown]
# También es útil definir el tipo de dato cuando leemos el archivo para evitar pérdidas de información. Por ejemplo, supongamos que tenemos un id que empieza con ceros, 000034.
# Cuando pandas lea ese dato, si no le decimos que es una string, lo va a leer como un número y vamos a perder los 0000.
#
# Para definir el tipo de dato podemos hacer lo siguiente:

# %%
data = pd.read_csv('listings.csv.gz', dtype = {'id':'str'})

# %%
data.id.tolist()[:10]
# Out:
# ['23726706',
#  '35815036',
#  '31553121',
#  '34745823',
#  '44586947',
#  '15801253',
#  '19572024',
#  '18801518',
#  '2973384',
#  '34985473']

# %% [markdown]
# ### Ejercicios:
# Descargar el archivo de distribución de empleo formal en el AMBA de este [link](https://www.datos.gob.ar/dataset/produccion-distribucion-empleo-formal-amba) (el que en su título dice hasta CLAE2)
# 1.   Calcular la cantidad de departamentos y sectores (CLAE 2 dígitos) qué emplean:
#
#   1.   solo hombres
#   2.   solo mujeres
#   3.   a ambos géneros
#   4.   pensar una estrategia para chequear que los datos son "buenos"
#
# 2. Calcular la remuneración media para hombres y para mujeres
# 3. Calcular la remuneración media para mujeres en el CLAE = 6
#
# Nota: realizar consideración acerca del promedio de promedios
